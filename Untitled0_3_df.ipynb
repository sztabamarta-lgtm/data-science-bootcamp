# %% [markdown]
# <a href="https://colab.research.google.com/github/sztabamarta-lgtm/data-science-bootcamp/blob/main/Untitled0_3_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__

import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
s = pd.Series(data=[3,4,1,5])
s
# Out:
# 0    3
# 1    4
# 2    1
# 3    5
# dtype: int64

# %%
s = pd.Series(data=[3,4,1,5], index=['a','b','c','d'], name='sample')
s
# Out:
# a    3
# b    4
# c    1
# d    5
# Name: sample, dtype: int64

# %%
price = pd.Series(data={'Apple':200, 'CD Projekt':60, 'Amazon':1900,'KGHM':np.nan})
price
# Out:
# Apple          200.0
# CD Projekt      60.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
price['CD Projekt']
# Out:
# np.float64(60.0)

# %%
price[1]
# Out:
# /tmp/ipython-input-4074423798.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   price[1]
# np.float64(60.0)

# %%
price.count()
# Out:
# np.int64(3)

# %%
price.value_counts()
# Out:
# 200     1
# 60      1
# 1900    1
# Name: count, dtype: int64

# %%
price.sum()
# Out:
# np.int64(2160)

# %%
price.std()
# Out:
# 1024.3046421841502

# %%
price.describe()
# Out:
# count       3.000000
# mean      720.000000
# std      1024.304642
# min        60.000000
# 25%       130.000000
# 50%       200.000000
# 75%      1050.000000
# max      1900.000000
# dtype: float64

# %%
price.describe().T
# Out:
# count       3.000000
# mean      720.000000
# std      1024.304642
# min        60.000000
# 25%       130.000000
# 50%       200.000000
# 75%      1050.000000
# max      1900.000000
# dtype: float64

# %%
price_pln= price.apply(lambda x: x*3.8)

# %%
price_pln
# Out:
# Apple          760.0
# CD Projekt     228.0
# Amazon        7220.0
# KGHM             NaN
# dtype: float64

# %%
df = pd.DataFrame(data=[12,12,32], index=['first','second','third'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third      32

# %%
df=pd.DataFrame(data={'WIG20':['PKN ORLEN','PKO BP'],
                      'mWIG40':['Amica','Playway']})
df
# Out:
#        WIG20   mWIG40
# 0  PKN ORLEN    Amica
# 1     PKO BP  Playway

# %%
df = pd.DataFrame(data=[[10,12,13],[23,12,10]], index=['first','second'], columns=['col_1','col_2','col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.index
# Out:
# Index(['first', 'second'], dtype='object')

# %%
df.values
# Out:
# array([[10, 12, 13],
#        [23, 12, 10]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 172.0+ bytes

# %%
df.describe()
# Out:
#            col_1  col_2     col_3
# count   2.000000    2.0   2.00000
# mean   16.500000   12.0  11.50000
# std     9.192388    0.0   2.12132
# min    10.000000   12.0  10.00000
# 25%    13.250000   12.0  10.75000
# 50%    16.500000   12.0  11.50000
# 75%    19.750000   12.0  12.25000
# max    23.000000   12.0  13.00000

# %%
df.describe().T
# Out:
#        count  mean       std   min    25%   50%    75%   max
# col_1    2.0  16.5  9.192388  10.0  13.25  16.5  19.75  23.0
# col_2    2.0  12.0  0.000000  12.0  12.00  12.0  12.00  12.0
# col_3    2.0  11.5  2.121320  10.0  10.75  11.5  12.25  13.0

# %%
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df['col_1']
# Out:
# first     10
# second    23
# Name: col_1, dtype: int64

# %%
type(df['col_1'])
# Out:
# pandas.core.series.Series

# %%
df[['col_1']]
# Out:
#         col_1
# first      10
# second     23

# %%
type(df[['col_1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.columns=['a','b','c']
df
# Out:
#          a   b   c
# first   10  12  13
# second  23  12  10

# %%
df.b
# Out:
# first     12
# second    12
# Name: b, dtype: int64

# %%
df['d']=df.a + df.c
df
# Out:
#          a   b   c   d
# first   10  12  13  23
# second  23  12  10  33

# %%
df = pd.DataFrame(data=[[10,12,13],[23,12,10]], index=['first','second'], columns=['col_1','col_2','col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df.loc['first']
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
df.iloc[0]
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
df.loc['first','col_2']
# Out:
# np.int64(12)

# %%
df.loc[:,'col_2']
# Out:
# first     12
# second    12
# Name: col_2, dtype: int64

# %%
df.iloc[0,1]
# Out:
# np.int64(12)
