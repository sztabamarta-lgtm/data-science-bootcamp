# %% [markdown]
# <a href="https://colab.research.google.com/github/sztabamarta-lgtm/data-science-bootcamp/blob/main/zapis_odczyt_danych_csv_excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(list(uploaded.keys())[0])

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#                Open      High       Low   Close    Volume
# Date
# 2025-08-06  770.000  773.6400  760.4601  771.99   9733910
# 2025-08-05  776.445  783.1299  763.0000  763.46  11640294
# 2025-08-04  760.000  776.8500  758.4100  776.37  15801727
# 2025-08-01  760.730  765.9999  745.3100  750.01  19028710
# 2025-07-31  775.200  784.7500  765.5100  773.44  38831098

# %%
import numpy as np
import pandas as pd

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data('META')
df.head()
# Out:
#                Open      High       Low   Close    Volume
# Date
# 2025-08-06  770.000  773.6400  760.4601  771.99   9733910
# 2025-08-05  776.445  783.1299  763.0000  763.46  11640294
# 2025-08-04  760.000  776.8500  758.4100  776.37  15801727
# 2025-08-01  760.730  765.9999  745.3100  750.01  19028710
# 2025-07-31  775.200  784.7500  765.5100  773.44  38831098

# %%
df.to_csv('meta.csv')

# %%
df_may = df[(df.index.month==5) &(df.index.year ==2025)]

# %%
df_may
# Out:
#                Open      High       Low   Close    Volume
# Date
# 2025-05-30  642.500  649.4099  632.7800  647.49  16240951
# 2025-05-29  651.645  653.3200  639.5000  645.05   8883436
# 2025-05-28  642.600  650.8800  642.5472  643.58   9042874
# 2025-05-27  635.410  643.0800  632.7500  642.32   9508367
# 2025-05-23  624.000  632.4450  622.6500  627.06   8454067
# 2025-05-22  634.050  643.2500  630.7100  636.57   8228443
# 2025-05-21  631.790  646.6100  630.1700  635.50  11464569
# 2025-05-20  636.010  639.3536  632.2600  637.10   6743473
# 2025-05-19  628.250  643.0000  627.8000  640.43   9592374
# 2025-05-16  637.955  640.4400  626.1500  640.34  18518972
# 2025-05-15  654.275  657.3100  638.5800  643.88  14341835
# 2025-05-14  661.210  662.6700  654.3100  659.36  12348179
# 2025-05-13  645.545  660.9200  642.8300  656.03  18570821
# 2025-05-12  630.920  640.3896  621.0300  639.43  21965085
# 2025-05-09  603.720  606.9700  591.7062  592.49  10427286
# ...

# %%
df_may.to_csv('meta_may.csv')

# %%
new_df=pd.read_csv('meta_may.csv')
new_df
# Out:
#           Date     Open      High       Low   Close    Volume
# 0   2025-05-30  642.500  649.4099  632.7800  647.49  16240951
# 1   2025-05-29  651.645  653.3200  639.5000  645.05   8883436
# 2   2025-05-28  642.600  650.8800  642.5472  643.58   9042874
# 3   2025-05-27  635.410  643.0800  632.7500  642.32   9508367
# 4   2025-05-23  624.000  632.4450  622.6500  627.06   8454067
# 5   2025-05-22  634.050  643.2500  630.7100  636.57   8228443
# 6   2025-05-21  631.790  646.6100  630.1700  635.50  11464569
# 7   2025-05-20  636.010  639.3536  632.2600  637.10   6743473
# 8   2025-05-19  628.250  643.0000  627.8000  640.43   9592374
# 9   2025-05-16  637.955  640.4400  626.1500  640.34  18518972
# 10  2025-05-15  654.275  657.3100  638.5800  643.88  14341835
# 11  2025-05-14  661.210  662.6700  654.3100  659.36  12348179
# 12  2025-05-13  645.545  660.9200  642.8300  656.03  18570821
# 13  2025-05-12  630.920  640.3896  621.0300  639.43  21965085
# ...

# %%
new_kat_df=pd.read_csv('katalog_produktow.csv')
new_kat_df
# Out:
#      ID_Produktu_Katalog                          Nazwa_Produktu  \
# 0                   1001                       Mieć na imię Ósmy
# 1                   1002                          Mało Zapalenie
# 2                   1003                          Kalendarz Głos
# 3                   1004                           Dzielnica Iść
# 4                   1005                           Lot Centralny
# ..                   ...                                     ...
# 96                  1097                         Z powodu Sukces
# 97                  1098                                On Kilka
# 98                  1099                   Słoneczny Zakończenie
# 99                  1100                            Rysunek Rola
# 100                 9999  Produkt Specjalny / Niezidentyfikowany
#
#      Cena_Katalogowa Kategoria_Produktu
# 0             339.36          Akcesoria
# 1             153.68              Biuro
# 2             291.73     Oprogramowanie
# ...

# %%
new_kat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 1001 to 9999
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Nazwa_Produktu      101 non-null    object
#  1   Cena_Katalogowa     101 non-null    float64
#  2   Kategoria_Produktu  101 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 3.2+ KB

# %%
df = pd.read_csv('london_bike.csv')
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df= df.set_index('timestamp')
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %%
new_kat_df = new_kat_df.set_index('ID_Produktu_Katalog')
new_kat_df.head()
# Out:
#                         Nazwa_Produktu  Cena_Katalogowa Kategoria_Produktu
# ID_Produktu_Katalog
# 1001                 Mieć na imię Ósmy           339.36          Akcesoria
# 1002                    Mało Zapalenie           153.68              Biuro
# 1003                    Kalendarz Głos           291.73     Oprogramowanie
# 1004                     Dzielnica Iść           307.01          Akcesoria
# 1005                     Lot Centralny           977.54        Elektronika

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17414 entries, 2015-01-04 00:00:00 to 2017-01-03 23:00:00
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cnt           17414 non-null  int64
#  1   t1            17414 non-null  float64
#  2   t2            17414 non-null  float64
#  3   hum           17414 non-null  float64
#  4   wind_speed    17414 non-null  float64
#  5   weather_code  17414 non-null  float64
#  6   is_holiday    17414 non-null  float64
#  7   is_weekend    17414 non-null  float64
#  8   season        17414 non-null  float64
# dtypes: float64(8), int64(1)
# memory usage: 1.8+ MB
