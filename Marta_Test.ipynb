# %% [markdown]
# <a href="https://colab.research.google.com/github/sztabamarta-lgtm/data-science-bootcamp/blob/main/Marta_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(list(uploaded.keys())[0])

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#      <input type="file" id="files-2d57d9ca-1b4f-4656-ad7e-768089df3cc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d57d9ca-1b4f-4656-ad7e-768089df3cc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_kat = pd.read_csv('katalog_produktow.csv')

df_kat.head()
# Out:
#    ID_Produktu_Katalog     Nazwa_Produktu  Cena_Katalogowa Kategoria_Produktu
# 0                 1001  Mieć na imię Ósmy           339.36          Akcesoria
# 1                 1002     Mało Zapalenie           153.68              Biuro
# 2                 1003     Kalendarz Głos           291.73     Oprogramowanie
# 3                 1004      Dzielnica Iść           307.01          Akcesoria
# 4                 1005      Lot Centralny           977.54        Elektronika

# %%
df_rap_kw = pd.read_csv('raport_kwartalny_sprzedaz.csv', encoding='latin1')
df_rap_kw.head()
# Out:
#   Data_Transakcji  ID_Produktu_Sprzedaz  Region  Ilosc_Sprzedana  \
# 0      2025-05-08                  1074  PóBnoc                1
# 1      2025-05-13                  1068  PóBnoc                5
# 2      2025-04-12                  1090  Wschód                2
# 3      2025-05-27                  1031  Zachód                1
# 4      2025-06-23                  1026  Wschód                5
#
#    Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy
# 0                        44.30              44.30
# 1                       126.45             632.25
# 2                      3974.94            7949.88
# 3                       230.14             230.14
# 4                       167.64             838.20

# %%
df_kat.head()
# Out:
#    ID_Produktu_Katalog     Nazwa_Produktu  Cena_Katalogowa Kategoria_Produktu
# 0                 1001  Mieć na imię Ósmy           339.36          Akcesoria
# 1                 1002     Mało Zapalenie           153.68              Biuro
# 2                 1003     Kalendarz Głos           291.73     Oprogramowanie
# 3                 1004      Dzielnica Iść           307.01          Akcesoria
# 4                 1005      Lot Centralny           977.54        Elektronika

# %%
df_rap_kw.head()
# Out:
#   Data_Transakcji  ID_Produktu_Sprzedaz  Region  Ilosc_Sprzedana  \
# 0      2025-05-08                  1074  PóBnoc                1
# 1      2025-05-13                  1068  PóBnoc                5
# 2      2025-04-12                  1090  Wschód                2
# 3      2025-05-27                  1031  Zachód                1
# 4      2025-06-23                  1026  Wschód                5
#
#    Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy
# 0                        44.30              44.30
# 1                       126.45             632.25
# 2                      3974.94            7949.88
# 3                       230.14             230.14
# 4                       167.64             838.20

# %%
merged_columns = pd.merge(df_rap_kw, df_kat, left_on='ID_Produktu_Sprzedaz', right_on='ID_Produktu_Katalog', how='left')

# %%
merged_columns.columns
# Out:
# Index(['Data_Transakcji', 'ID_Produktu_Sprzedaz', 'Region', 'Ilosc_Sprzedana',
#        'Cena_Jednostkowa_Transakcji', 'Wartosc_Sprzedazy',
#        'ID_Produktu_Katalog', 'Nazwa_Produktu', 'Cena_Katalogowa',
#        'Kategoria_Produktu'],
#       dtype='object')

# %%
merged_columns
# Out:
#      Data_Transakcji  ID_Produktu_Sprzedaz    Region  Ilosc_Sprzedana  \
# 0         2025-05-08                  1074    PóBnoc                1
# 1         2025-05-13                  1068    PóBnoc                5
# 2         2025-04-12                  1090    Wschód                2
# 3         2025-05-27                  1031    Zachód                1
# 4         2025-06-23                  1026    Wschód                5
# ...              ...                   ...       ...              ...
# 7495      2025-05-18                  1062    Wschód                5
# 7496      2025-06-24                  1067    Zachód                5
# 7497      2025-06-07                  1014    PóBnoc                3
# 7498      2025-05-14                  1004    Wschód                3
# 7499      2025-06-13                  1042  PoBudnie                4
#
#       Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy  ID_Produktu_Katalog  \
# ...

# %%
merged_columns.ID_Produktu_Katalog > 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 7495    True
# 7496    True
# 7497    True
# 7498    True
# 7499    True
# Name: ID_Produktu_Katalog, Length: 7500, dtype: bool

# %%
merged_columns[merged_columns.ID_Produktu_Katalog > 0]
# Out:
#      Data_Transakcji  ID_Produktu_Sprzedaz    Region  Ilosc_Sprzedana  \
# 0         2025-05-08                  1074    PóBnoc                1
# 1         2025-05-13                  1068    PóBnoc                5
# 2         2025-04-12                  1090    Wschód                2
# 3         2025-05-27                  1031    Zachód                1
# 4         2025-06-23                  1026    Wschód                5
# ...              ...                   ...       ...              ...
# 7495      2025-05-18                  1062    Wschód                5
# 7496      2025-06-24                  1067    Zachód                5
# 7497      2025-06-07                  1014    PóBnoc                3
# 7498      2025-05-14                  1004    Wschód                3
# 7499      2025-06-13                  1042  PoBudnie                4
#
#       Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy  ID_Produktu_Katalog  \
# ...

# %%
merged_columns.ID_Produktu_Katalog.notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 7495    True
# 7496    True
# 7497    True
# 7498    True
# 7499    True
# Name: ID_Produktu_Katalog, Length: 7500, dtype: bool

# %%
missing_values_in_merged_columns=merged_columns[merged_columns.ID_Produktu_Katalog.isnull()]
missing_values_in_merged_columns
# Out:
#      Data_Transakcji  ID_Produktu_Sprzedaz    Region  Ilosc_Sprzedana  \
# 168       2025-04-14                  2318    PóBnoc                1
# 210       2025-05-21                  2967    PóBnoc                4
# 265       2025-05-11                  2377    Wschód                1
# 395       2025-04-02                  2041    Wschód                5
# 467       2025-04-29                  2017    PóBnoc                2
# ...              ...                   ...       ...              ...
# 7275      2025-05-05                  2461  PoBudnie                3
# 7358      2025-05-09                  2335    PóBnoc                4
# 7401      2025-06-28                  2657  PoBudnie                5
# 7436      2025-04-10                  2149    PóBnoc                5
# 7481      2025-06-06                  2101    PóBnoc                4
#
#       Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy  ID_Produktu_Katalog  \
# ...

# %%
matched_vaulues_in_merged_columns = merged_columns[merged_columns.ID_Produktu_Katalog.notna()]
matched_vaulues_in_merged_columns
# Out:
#      Data_Transakcji  ID_Produktu_Sprzedaz    Region  Ilosc_Sprzedana  \
# 0         2025-05-08                  1074    PóBnoc                1
# 1         2025-05-13                  1068    PóBnoc                5
# 2         2025-04-12                  1090    Wschód                2
# 3         2025-05-27                  1031    Zachód                1
# 4         2025-06-23                  1026    Wschód                5
# ...              ...                   ...       ...              ...
# 7495      2025-05-18                  1062    Wschód                5
# 7496      2025-06-24                  1067    Zachód                5
# 7497      2025-06-07                  1014    PóBnoc                3
# 7498      2025-05-14                  1004    Wschód                3
# 7499      2025-06-13                  1042  PoBudnie                4
#
#       Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy  ID_Produktu_Katalog  \
# ...

# %%
merged_columns_inner = pd.merge(df_rap_kw, df_kat, left_on='ID_Produktu_Sprzedaz', right_on='ID_Produktu_Katalog', how='inner')

# %%
merged_columns_inner
# Out:
#      Data_Transakcji  ID_Produktu_Sprzedaz    Region  Ilosc_Sprzedana  \
# 0         2025-05-08                  1074    PóBnoc                1
# 1         2025-05-13                  1068    PóBnoc                5
# 2         2025-04-12                  1090    Wschód                2
# 3         2025-05-27                  1031    Zachód                1
# 4         2025-06-23                  1026    Wschód                5
# ...              ...                   ...       ...              ...
# 7341      2025-05-18                  1062    Wschód                5
# 7342      2025-06-24                  1067    Zachód                5
# 7343      2025-06-07                  1014    PóBnoc                3
# 7344      2025-05-14                  1004    Wschód                3
# 7345      2025-06-13                  1042  PoBudnie                4
#
#       Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy  ID_Produktu_Katalog  \
# ...

# %%
matched_vaulues_in_merged_columns.Wartosc_Sprzedazy.sum()
# Out:
# np.float64(31336539.21)

# %%
merged_columns_inner.Wartosc_Sprzedazy.sum()
# Out:
# np.float64(31336539.21)

# %%
matched_vaulues_in_merged_columns.columns
# Out:
# Index(['Data_Transakcji', 'ID_Produktu_Sprzedaz', 'Region', 'Ilosc_Sprzedana',
#        'Cena_Jednostkowa_Transakcji', 'Wartosc_Sprzedazy',
#        'ID_Produktu_Katalog', 'Nazwa_Produktu', 'Cena_Katalogowa',
#        'Kategoria_Produktu'],
#       dtype='object')

# %%
merged_columns_inner.columns
# Out:
# Index(['Data_Transakcji', 'ID_Produktu_Sprzedaz', 'Region', 'Ilosc_Sprzedana',
#        'Cena_Jednostkowa_Transakcji', 'Wartosc_Sprzedazy',
#        'ID_Produktu_Katalog', 'Nazwa_Produktu', 'Cena_Katalogowa',
#        'Kategoria_Produktu'],
#       dtype='object')

# %%
merged_columns_inner['Srednia_Cena_Wyliczona'] = merged_columns_inner.Wartosc_Sprzedazy/merged_columns_inner.Ilosc_Sprzedana
merged_columns_inner
# Out:
#      Data_Transakcji  ID_Produktu_Sprzedaz    Region  Ilosc_Sprzedana  \
# 0         2025-05-08                  1074    PóBnoc                1
# 1         2025-05-13                  1068    PóBnoc                5
# 2         2025-04-12                  1090    Wschód                2
# 3         2025-05-27                  1031    Zachód                1
# 4         2025-06-23                  1026    Wschód                5
# ...              ...                   ...       ...              ...
# 7341      2025-05-18                  1062    Wschód                5
# 7342      2025-06-24                  1067    Zachód                5
# 7343      2025-06-07                  1014    PóBnoc                3
# 7344      2025-05-14                  1004    Wschód                3
# 7345      2025-06-13                  1042  PoBudnie                4
#
#       Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy  ID_Produktu_Katalog  \
# ...

# %%
srednia_cena_2 = merged_columns_inner.groupby('Nazwa_Produktu')[['Srednia_Cena_Wyliczona', 'Cena_Katalogowa']].mean().reset_index()
srednia_cena_2
# Out:
#           Nazwa_Produktu  Srednia_Cena_Wyliczona  Cena_Katalogowa
# 0             9 Kolejowy              368.868852           368.55
# 1             Ani Pływać              688.394667           688.88
# 2        Arabski Funkcja              122.544054           122.38
# 3       Arabski Wyglądać             3276.727183          3261.26
# 4     Bliski Wykonywanie              723.956353           726.90
# ..                   ...                     ...              ...
# 96    Związany Przyprawa              657.908031           654.37
# 97             Św. Złoto              231.084795           231.83
# 98          Świat Statek              306.640898           305.78
# 99          Świeca Przed             1504.632286          1499.88
# 100  Świecić Odnosić się              678.843479           677.52
#
# [101 rows x 3 columns]

# %%
matched_vaulues_in_merged_columns['Wartosc_wyliczona'] = matched_vaulues_in_merged_columns.Wartosc_Sprzedazy/matched_vaulues_in_merged_columns.Ilosc_Sprzedana
# Out:
# /tmp/ipython-input-385344534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_vaulues_in_merged_columns['Wartosc_wyliczona'] = matched_vaulues_in_merged_columns.Wartosc_Sprzedazy/matched_vaulues_in_merged_columns.Ilosc_Sprzedana

# %%
matched_vaulues_in_merged_columns
# Out:
#      Data_Transakcji  ID_Produktu_Sprzedaz    Region  Ilosc_Sprzedana  \
# 0         2025-05-08                  1074    PóBnoc                1
# 1         2025-05-13                  1068    PóBnoc                5
# 2         2025-04-12                  1090    Wschód                2
# 3         2025-05-27                  1031    Zachód                1
# 4         2025-06-23                  1026    Wschód                5
# ...              ...                   ...       ...              ...
# 7495      2025-05-18                  1062    Wschód                5
# 7496      2025-06-24                  1067    Zachód                5
# 7497      2025-06-07                  1014    PóBnoc                3
# 7498      2025-05-14                  1004    Wschód                3
# 7499      2025-06-13                  1042  PoBudnie                4
#
#       Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy  ID_Produktu_Katalog  \
# ...

# %%
srednia_cena = matched_vaulues_in_merged_columns.groupby('Nazwa_Produktu')[['Wartosc_wyliczona', 'Cena_Katalogowa']].mean().reset_index()
srednia_cena
# Out:
#           Nazwa_Produktu  Wartosc_wyliczona  Cena_Katalogowa
# 0             9 Kolejowy         368.868852           368.55
# 1             Ani Pływać         688.394667           688.88
# 2        Arabski Funkcja         122.544054           122.38
# 3       Arabski Wyglądać        3276.727183          3261.26
# 4     Bliski Wykonywanie         723.956353           726.90
# ..                   ...                ...              ...
# 96    Związany Przyprawa         657.908031           654.37
# 97             Św. Złoto         231.084795           231.83
# 98          Świat Statek         306.640898           305.78
# 99          Świeca Przed        1504.632286          1499.88
# 100  Świecić Odnosić się         678.843479           677.52
#
# [101 rows x 3 columns]

# %%
srednia_cena['Roznica_procentowa']=(srednia_cena.Wartosc_wyliczona-srednia_cena.Cena_Katalogowa)/srednia_cena.Cena_Katalogowa *100
srednia_cena
# Out:
#           Nazwa_Produktu  Wartosc_wyliczona  Cena_Katalogowa  \
# 0             9 Kolejowy         368.868852           368.55
# 1             Ani Pływać         688.394667           688.88
# 2        Arabski Funkcja         122.544054           122.38
# 3       Arabski Wyglądać        3276.727183          3261.26
# 4     Bliski Wykonywanie         723.956353           726.90
# ..                   ...                ...              ...
# 96    Związany Przyprawa         657.908031           654.37
# 97             Św. Złoto         231.084795           231.83
# 98          Świat Statek         306.640898           305.78
# 99          Świeca Przed        1504.632286          1499.88
# 100  Świecić Odnosić się         678.843479           677.52
#
#      Roznica_procentowa
# 0              0.086515
# 1             -0.070453
# 2              0.134053
# 3              0.474270
# 4             -0.404959
# ..                  ...
# 96             0.540677
# 97            -0.321445
# ...

# %%
srednia_cena_2['Roznica_procentowa']=(srednia_cena_2.Srednia_Cena_Wyliczona-srednia_cena_2.Cena_Katalogowa)/srednia_cena_2.Cena_Katalogowa *100
srednia_cena_2
# Out:
#           Nazwa_Produktu  Srednia_Cena_Wyliczona  Cena_Katalogowa  \
# 0             9 Kolejowy              368.868852           368.55
# 1             Ani Pływać              688.394667           688.88
# 2        Arabski Funkcja              122.544054           122.38
# 3       Arabski Wyglądać             3276.727183          3261.26
# 4     Bliski Wykonywanie              723.956353           726.90
# ..                   ...                     ...              ...
# 96    Związany Przyprawa              657.908031           654.37
# 97             Św. Złoto              231.084795           231.83
# 98          Świat Statek              306.640898           305.78
# 99          Świeca Przed             1504.632286          1499.88
# 100  Świecić Odnosić się              678.843479           677.52
#
#      Roznica_procentowa
# 0              0.086515
# 1             -0.070453
# 2              0.134053
# 3              0.474270
# 4             -0.404959
# ...

# %%
srednia_cena_sorted_abs = srednia_cena_sorted.sort_values(by='Roznica_procentowa_abs', ascending=False)
display(srednia_cena_sorted_abs)
# Out:
#        Nazwa_Produktu  Wartosc_wyliczona  Cena_Katalogowa  Roznica_procentowa  \
# 37    Miara Przyczyna         300.874108           429.84          -30.003232
# 79   Umiejętność Zima        1371.081415          1382.98           -0.860358
# 8   Ciekawy Mężczyzna        3671.365925          3641.67            0.815448
# 45       Oddać Klient         133.413196           132.35            0.803322
# 14      Dzielnica Iść         304.696965           307.01           -0.753407
# ..                ...                ...              ...                 ...
# 48   Owad Obowiązywać         139.914054           139.96           -0.032828
# 19     Jedyny Zamykać          58.131655            58.15           -0.031547
# 13    Drewniany Ramię         156.385254           156.43           -0.028605
# 15     Gatunek Moneta        3501.626475          3501.06            0.016180
# 18       Istnieć Woda         588.509437           588.47            0.006702
#
#     Roznica_procentowa_abs
# ...

# %%
df_rap_kw['Niezgodnosci_Sprzedazy'] = (df_rap_kw.Wartosc_Sprzedazy - (df_rap_kw.Cena_Jednostkowa_Transakcji*df_rap_kw.Ilosc_Sprzedana)).round(2)
df_rap_kw
# Out:
#      Data_Transakcji  ID_Produktu_Sprzedaz    Region  Ilosc_Sprzedana  \
# 0         2025-05-08                  1074    PóBnoc                1
# 1         2025-05-13                  1068    PóBnoc                5
# 2         2025-04-12                  1090    Wschód                2
# 3         2025-05-27                  1031    Zachód                1
# 4         2025-06-23                  1026    Wschód                5
# ...              ...                   ...       ...              ...
# 7495      2025-05-18                  1062    Wschód                5
# 7496      2025-06-24                  1067    Zachód                5
# 7497      2025-06-07                  1014    PóBnoc                3
# 7498      2025-05-14                  1004    Wschód                3
# 7499      2025-06-13                  1042  PoBudnie                4
#
#       Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy  Niezgodnosci_Sprzedazy
# ...

# %%
df_rap_kw['Niezgodnosci_Sprzedazy'] != 0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7495    False
# 7496    False
# 7497    False
# 7498    False
# 7499    False
# Name: Niezgodnosci_Sprzedazy, Length: 7500, dtype: bool

# %%
df_rap_kw[df_rap_kw['Niezgodnosci_Sprzedazy'] != 0]
# Out:
#      Data_Transakcji  ID_Produktu_Sprzedaz    Region  Ilosc_Sprzedana  \
# 16        2025-05-14                  1038    Zachód                1
# 67        2025-04-02                  1066    PóBnoc                4
# 73        2025-04-14                  1030    Zachód                1
# 120       2025-04-19                  1060  PoBudnie                4
# 130       2025-06-01                  1035    Zachód                1
# ...              ...                   ...       ...              ...
# 7366      2025-04-09                  1041    Wschód                3
# 7418      2025-06-26                  1091    Zachód                3
# 7460      2025-04-22                  1100    PóBnoc                3
# 7471      2025-04-15                  1060    Zachód                3
# 7486      2025-04-27                  1023    Zachód                1
#
#       Cena_Jednostkowa_Transakcji  Wartosc_Sprzedazy  Niezgodnosci_Sprzedazy
# ...
