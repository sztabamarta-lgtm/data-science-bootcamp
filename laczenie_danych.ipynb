# %% [markdown]
# <a href="https://colab.research.google.com/github/sztabamarta-lgtm/data-science-bootcamp/blob/main/laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
del apple

# %%
del amazon
del google
del uber

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1254 entries, 2025-08-06 to 2020-08-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1254 non-null   float64
#  1   High    1254 non-null   float64
#  2   Low     1254 non-null   float64
#  3   Close   1254 non-null   float64
#  4   Volume  1254 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.8 KB

# %%
apple.head()
# Out:
#                Open    High      Low   Close     Volume
# Date
# 2025-08-06  205.630  215.38  205.590  213.25  108483103
# 2025-08-05  203.400  205.34  202.160  202.92   44155079
# 2025-08-04  204.505  207.88  201.675  203.35   75109298
# 2025-08-01  210.865  213.58  201.500  202.38  104434473
# 2025-07-31  208.490  209.84  207.160  207.57   80698431

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2025-08-06     205.630      215.38    205.590       213.25     108483103
# 2025-08-05     203.400      205.34    202.160       202.92      44155079
# 2025-08-04     204.505      207.88    201.675       203.35      75109298
# 2025-08-01     210.865      213.58    201.500       202.38     104434473
# 2025-07-31     208.490      209.84    207.160       207.57      80698431

# %%
amazon.head()
# Out:
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume
# Date
# 2025-08-06       214.69       222.65      213.74        222.31       54823045
# 2025-08-05       213.05       216.30      212.87        213.75       51505121
# 2025-08-04       217.40       217.44      211.42        211.65       77890146
# 2025-08-01       217.21       220.44      212.80        214.75      122258801
# 2025-07-31       235.77       236.53      231.40        234.11      104357263

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis=1)

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')
df.describe().T
# Out:
#                 count        mean         std         min         25%  \
# apple_open    1254.00      168.57       36.11      101.93      140.80
# apple_high    1254.00      170.45       36.36      107.45      142.64
# apple_low     1254.00      166.82       35.94      100.54      139.30
# apple_close   1254.00      168.72       36.19      104.19      141.05
# apple_volume  1254.00 78318756.88 39308537.13 23260251.00 51421456.00
# amazon_open   1254.00      157.89       35.42       82.80      132.00
# amazon_high   1254.00      159.78       35.53       83.48      133.60
# amazon_low    1254.00      155.84       35.22       81.43      130.44
# amazon_close  1254.00      157.84       35.40       81.82      131.93
# amazon_volume 1254.00 61529774.58 29037642.94 15007497.00 41983307.25
# google_open   1254.00      131.30       31.37       69.88      105.12
# google_high   1254.00      132.82       31.61       71.64      106.51
# google_low    1254.00      129.87       31.08       69.85      104.05
# google_close  1254.00      131.36       31.35       70.21      105.27
# google_volume 1254.00 32286130.35 13704993.94  9346519.00 23363734.50
# uber_open     1254.00       50.89       18.74       20.37       34.56
# uber_high     1254.00       51.78       18.91       21.13       35.18
# uber_low      1254.00       49.98       18.51       19.89       33.87
# uber_close    1254.00       50.89       18.72       20.46       34.55
# uber_volume   1254.00 23799470.82 16285180.29  5200356.00 15620855.50
#
#                       50%         75%          max
# apple_open         166.69      192.38       257.91
# apple_high         168.31      193.83       259.81
# apple_low          164.96      190.78       257.35
# apple_close        166.50      192.29       258.74
# apple_volume  69083209.00 92931273.25 354772009.00
# amazon_open        161.12      179.93       239.01
# amazon_high        162.97      181.85       242.52
# amazon_low         159.22      177.26       238.03
# amazon_close       161.20      179.49       242.06
# amazon_volume 55015177.50 72899012.25 272661720.00
# google_open        131.39      154.26       203.39
# google_high        133.02      156.29       207.05
# google_low         129.99      152.41       202.81
# google_close       131.95      154.47       206.38
# google_volume 28925675.00 36930366.50 127747554.00
# uber_open           47.02       67.00        97.50
# uber_high           47.71       68.42        97.72
# uber_low            46.29       65.99        96.10
# uber_close          47.05       66.99        97.48
# uber_volume   20138021.00 27670388.50 364261230.00

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.54
# apple_high           1.00        1.00       1.00         1.00         -0.53
# apple_low            1.00        1.00       1.00         1.00         -0.55
# apple_close          1.00        1.00       1.00         1.00         -0.54
# apple_volume        -0.54       -0.53      -0.55        -0.54          1.00
# amazon_open          0.56        0.56       0.56         0.56         -0.13
# amazon_high          0.56        0.56       0.56         0.56         -0.12
# amazon_low           0.56        0.56       0.56         0.56         -0.14
# amazon_close         0.56        0.56       0.56         0.56         -0.13
# amazon_volume       -0.51       -0.50      -0.52        -0.51          0.60
# google_open          0.87        0.87       0.87         0.87         -0.48
# google_high          0.87        0.87       0.87         0.87         -0.48
# google_low           0.87        0.87       0.87         0.87         -0.49
# google_close         0.87        0.87       0.87         0.87         -0.48
# google_volume       -0.10       -0.09      -0.11        -0.10          0.28
# uber_open            0.66        0.66       0.66         0.66         -0.35
# uber_high            0.66        0.66       0.66         0.66         -0.35
# uber_low             0.66        0.66       0.66         0.66         -0.36
# uber_close           0.66        0.66       0.66         0.66         -0.35
# uber_volume         -0.04       -0.04      -0.05        -0.05          0.14
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open            0.56         0.56        0.56          0.56
# apple_high            0.56         0.56        0.56          0.56
# apple_low             0.56         0.56        0.56          0.56
# apple_close           0.56         0.56        0.56          0.56
# apple_volume         -0.13        -0.12       -0.14         -0.13
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.33        -0.32       -0.35         -0.33
# google_open           0.75         0.75        0.75          0.75
# google_high           0.75         0.75        0.75          0.75
# google_low            0.75         0.76        0.76          0.76
# google_close          0.75         0.75        0.75          0.76
# google_volume        -0.09        -0.08       -0.10         -0.09
# uber_open             0.80         0.80        0.81          0.80
# uber_high             0.80         0.80        0.81          0.81
# uber_low              0.80         0.80        0.80          0.80
# uber_close            0.80         0.80        0.80          0.80
# uber_volume          -0.09        -0.09       -0.10         -0.10
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open             -0.51         0.87         0.87        0.87
# apple_high             -0.50         0.87         0.87        0.87
# apple_low              -0.52         0.87         0.87        0.87
# apple_close            -0.51         0.87         0.87        0.87
# apple_volume            0.60        -0.48        -0.48       -0.49
# amazon_open            -0.33         0.75         0.75        0.75
# amazon_high            -0.32         0.75         0.75        0.76
# amazon_low             -0.35         0.75         0.75        0.76
# amazon_close           -0.33         0.75         0.75        0.76
# amazon_volume           1.00        -0.50        -0.49       -0.50
# google_open            -0.50         1.00         1.00        1.00
# google_high            -0.49         1.00         1.00        1.00
# google_low             -0.50         1.00         1.00        1.00
# google_close           -0.50         1.00         1.00        1.00
# google_volume           0.44        -0.12        -0.11       -0.14
# uber_open              -0.46         0.74         0.74        0.74
# uber_high              -0.45         0.74         0.73        0.74
# uber_low               -0.47         0.74         0.74        0.74
# uber_close             -0.46         0.73         0.73        0.74
# uber_volume             0.23        -0.05        -0.05       -0.06
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open             0.87          -0.10       0.66       0.66      0.66
# apple_high             0.87          -0.09       0.66       0.66      0.66
# apple_low              0.87          -0.11       0.66       0.66      0.66
# apple_close            0.87          -0.10       0.66       0.66      0.66
# apple_volume          -0.48           0.28      -0.35      -0.35     -0.36
# amazon_open            0.75          -0.09       0.80       0.80      0.80
# amazon_high            0.75          -0.08       0.80       0.80      0.80
# amazon_low             0.75          -0.10       0.81       0.81      0.80
# amazon_close           0.76          -0.09       0.80       0.81      0.80
# amazon_volume         -0.50           0.44      -0.46      -0.45     -0.47
# google_open            1.00          -0.12       0.74       0.74      0.74
# google_high            1.00          -0.11       0.74       0.73      0.74
# google_low             1.00          -0.14       0.74       0.74      0.74
# google_close           1.00          -0.13       0.74       0.74      0.74
# google_volume         -0.13           1.00      -0.07      -0.07     -0.08
# uber_open              0.74          -0.07       1.00       1.00      1.00
# uber_high              0.74          -0.07       1.00       1.00      1.00
# uber_low               0.74          -0.08       1.00       1.00      1.00
# uber_close             0.74          -0.07       1.00       1.00      1.00
# uber_volume           -0.06           0.20      -0.17      -0.16     -0.18
#
#                uber_close  uber_volume
# apple_open           0.66        -0.04
# apple_high           0.66        -0.04
# apple_low            0.66        -0.05
# apple_close          0.66        -0.05
# apple_volume        -0.35         0.14
# amazon_open          0.80        -0.09
# amazon_high          0.80        -0.09
# amazon_low           0.80        -0.10
# amazon_close         0.80        -0.10
# amazon_volume       -0.46         0.23
# google_open          0.73        -0.05
# google_high          0.73        -0.05
# google_low           0.74        -0.06
# google_close         0.74        -0.06
# google_volume       -0.07         0.20
# uber_open            1.00        -0.17
# uber_high            1.00        -0.16
# uber_low             1.00        -0.18
# uber_close           1.00        -0.17
# uber_volume         -0.17         1.00

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.56          0.87        0.66
# amazon_close         0.56          1.00          0.76        0.80
# google_close         0.87          0.76          1.00        0.74
# uber_close           0.66          0.80          0.74        1.00

# %%
closes = [col for col in df.columns if col.endswith('close') or col.endswith('volume')]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df[closes].corr()
# Out:
#                apple_close  apple_volume  amazon_close  amazon_volume  \
# apple_close           1.00         -0.54          0.56          -0.51
# apple_volume         -0.54          1.00         -0.13           0.60
# amazon_close          0.56         -0.13          1.00          -0.33
# amazon_volume        -0.51          0.60         -0.33           1.00
# google_close          0.87         -0.48          0.76          -0.50
# google_volume        -0.10          0.28         -0.09           0.44
# uber_close            0.66         -0.35          0.80          -0.46
# uber_volume          -0.05          0.14         -0.10           0.23
#
#                google_close  google_volume  uber_close  uber_volume
# apple_close            0.87          -0.10        0.66        -0.05
# apple_volume          -0.48           0.28       -0.35         0.14
# amazon_close           0.76          -0.09        0.80        -0.10
# amazon_volume         -0.50           0.44       -0.46         0.23
# google_close           1.00          -0.13        0.74        -0.06
# google_volume         -0.13           1.00       -0.07         0.20
# uber_close             0.74          -0.07        1.00        -0.17
# uber_volume           -0.06           0.20       -0.17         1.00
